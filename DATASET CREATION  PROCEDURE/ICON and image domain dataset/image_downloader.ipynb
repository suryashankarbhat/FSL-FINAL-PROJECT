# %%
#referenced from https://github.com/gurugaurav/bing_image_downloader
# change name from in the download function from hospital_bed_icon to required name  

pip install bing-image-downloader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bing_image_downloader import downloader
downloader.download('hospital_bed_icon', limit=100,  output_dir='bed', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to /Users/suryahankar/bed/hospital_bed_icon
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 18 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn4.vectorstock.com/i/1000x1000/37/48/woman-on-hospital-bed-icon-vector-19133748.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn1.iconfinder.com/data/icons/medical-and-healthcare-16/232/70-512.png
# [!] Issue getting: https://cdn1.iconfinder.com/data/icons/medical-and-healthcare-16/232/70-512.png
# [!] Error:: HTTP Error 525:
# [%] Downloading Image #2 from https://www.nicepng.com/png/detail/222-2225957_patient-on-bed-icon-png-lying-archives-.png
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://thumbs.dreamstime.com/z/black-hospital-bed-logo-icon-vector-134125631.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.iconshock.com/srcOg/80895
# [%] File Downloaded !
#
# ...
